# %%
import sys
import os
import pandas as pd
import geopandas as gpd
import numpy as np
import shapely
import json


# path to folder to CityGeoTools
folder = "/home/max/Urban_code/git/CityGeoTools"
sys.path.append(folder)

from metrics.data import CityInformationModel as BaseModel
from metrics.calculations import CityMetricsMethods as CityMetrics
from metrics.calculations import utils
# Out:
# /usr/local/lib/python3.8/dist-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.3-CAPI-1.16.1). Conversions between both will be slow.
#   warnings.warn(
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# ...

# %%
city_model = BaseModel.CityInformationModel(city_name="Saint-Petersburg", city_crs=32636, cwd="../")
city_model.update_layer("Buildings", "/home/max/Urban_code/buildings_test.geojson")
# Out:
# Validation of Buildings layer...
# Buildings layer loaded successfully!

# %%
all_methods = city_model.methods.get_list_of_methods()
available_methods = city_model.methods.get_list_of_available_methods()

for method in all_methods:
    if method in available_methods:
        print(method, "--> available")
    else:
        print(method, "--> unavailable")
# Out:
# traffic_calculator --> unavailable
# visibility_analysis --> available
# weighted_voronoi --> available
# blocks_clusterization --> unavailable
# services_clusterization --> unavailable
# spacematrix --> unavailable
# accessibility_isochrones --> unavailable
# diversity --> unavailable
# collocation_matrix --> unavailable
# masterplan --> available

# %%
indicators = {
    'land_area' : None, # Площадь змелеьного участка
    'dev_land_procent' : None, # Процент застроенности земельного участка
    'dev_land_area' : None, # Площадь застройки
    'dev_land_density' : None, # Плотность застройки територии
    'land_living_area' : 100, # Площадь  жилой застройки
    'dev_living_density' : None, # Плотность  жилой застройкой
    'population' : None, # Численность жителей
    'population_density' : None, # Плотность населения
    'living_area_provision' : None, # Жилищная обеспеченность
    'land_business_area' : None, # Общественно деловая площадь в жилой застройке
    'building_height_mode' : None, # Мода этажности рядовой застройки
    'living' : 70, # Процент жилой застройки
    'commerce' : 30 # Процент коммерческой застройки
    }

# %%
polygon = ('/home/max/Urban_code/Data/polygon.geojson') # Path to the polygon

# %%
from metrics.calculations import utils

# %%
Masterplan = CityMetrics.Masterplan(city_model).get_masterplan(polygon=polygon, **indicators)['Значение']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/max/Urban_code/git/CityGeoTools/notebook_examples/masterplan.ipynb Ячейка 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/max/Urban_code/git/CityGeoTools/notebook_examples/masterplan.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> Masterplan = CityMetrics.Masterplan(city_model).get_masterplan(polygon=polygon, **indicators)['Значение']
#
# TypeError: get_masterplan() missing 1 required positional argument: 'buildings'
