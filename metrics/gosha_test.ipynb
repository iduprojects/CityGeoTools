# %%
import sys

# path to folder to CityGeoTools
folder = "/home/gk/vscode/metrics_accs/CityGeoTools2/CityGeoTools"
sys.path.append(folder)

from metrics.data import CityInformationModel as BaseModel
# Out:
# /home/gk/.local/lib/python3.8/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# ...

# %%
city_model = BaseModel.CityInformationModel(city_name="saint-petersburg", city_crs=32636, 
                                            cwd="/home/gk/vscode/metrics_accs/CityGeoTools2/CityGeoTools")
city_model

# %%
city_model.update_layer("MobilityGraph", "/home/gk/jupyter/mobility_graph_whole.graphml")
city_model.update_layer("Blocks", "/home/gk/jupyter/accessibility_paper/districts_splitted_Санкт-Петербург.geojson")
# Out:
# Validation of MobilityGraph layer...
# {'type': True, 'walk value in type': True, 'public transport in type': True, 'length_meter': True, 'time_min': True} {'x': True, 'y': True, 'stop': True}
# MobilityGraph layer loaded successfully!
# Validation of Blocks layer...
# Blocks layer loaded successfully!

# %%
if city_model.methods.if_method_available("blocks_accessibility"):
    print('True')
else:
    print('False')
# Out:
# True

# %%
print("All methods implemented in CityGeoTools:\n")

all_methods = city_model.methods.get_list_of_methods()
available_methods = city_model.methods.get_list_of_available_methods()

for method in all_methods:
    if method in available_methods:
        print(method, "--> available")
    else:
        print(method, "--> unavailable")
# Out:
# All methods implemented in CityGeoTools:
#
# traffics_calculation --> unavailable
# visibility_analysis --> unavailable
# weighted_voronoi --> available
# blocks_clusterization --> unavailable
# services_clusterization --> unavailable
# spacematrix --> unavailable
# mobility_analysis --> available
# diversity --> unavailable
# collocation_matrix --> unavailable
# master_plan --> unavailable
# mobility_analysis_v2 --> available
# coverage_zone --> unavailable
# blocks_accessibility --> available

# %%
from metrics.calculations.blocks_accessibility import Blocks_accessibility as BA

# %%
BA(city_model).get_accessibility(5553)
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': '0',
#    'type': 'Feature',
#    'properties': {'id': 2, 'accessibility_time': 304.0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[348127.25284134725, 6655861.068149528],
#        [347936.6088473551, 6655238.318894349],
#        [347537.29596785945, 6655358.17050022],
#        [347725.0727882355, 6655972.101565764],
#        [348106.3372888388, 6655852.007254406],
#        [348127.25284134725, 6655861.068149528]]]]}},
#   {'id': '1',
#    'type': 'Feature',
#    'properties': {'id': 3, 'accessibility_time': 347.0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[353093.4007789014, 6646363.803563473],
#        [353017.2480168275, 6646265.379500542],
#        [352755.3701099163, 6646480.595108769],
#        [352651.24161350436, 6646563.562922144],
#        [352592.56834767037, 6646616.069787411],
#        [352640.9601145146, 6646624.285864812],
# ...
